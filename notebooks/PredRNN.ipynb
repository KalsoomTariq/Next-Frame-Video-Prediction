# %%
import cv2
import os

train_dir = "/kaggle/input/ucf101-action-recognition/train"
actions = {"Biking","PushUps","JumpingJack","WalkingWithDog","WallPushups"}
output_base_dir = "/kaggle/working/extracted_frames"


def extract_and_resize_frames(video_path, output_dir, frame_size=(64, 64)):
    cap = cv2.VideoCapture(video_path)
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    os.makedirs(output_dir, exist_ok=True)
    
    for i in range(frame_count):
        ret, frame = cap.read()
        if not ret:
            break
        resized_frame = cv2.resize(frame, frame_size)  # Resize to 64x64
        frame_path = os.path.join(output_dir, f"frame_{i:04d}.jpg")
        cv2.imwrite(frame_path, resized_frame)
    
    cap.release()
    print(f"Frames resized to {frame_size} and saved to {output_dir}")

# Extract and resize frames from a video
import os

# Function to extract frames for all videos in an action directory
def process_videos_for_actions(actions, train_dir, output_base_dir, frame_size=(64, 64)):
    for action in actions:
        # Path to the current action directory
        action_dir = os.path.join(train_dir, action)
        if not os.path.exists(action_dir):
            print(f"Directory not found for action: {action}")
            continue

        # Output directory for extracted frames of this action
        action_output_dir = os.path.join(output_base_dir, action)
        os.makedirs(action_output_dir, exist_ok=True)

        # Process each video in the action directory
        for video_file in os.listdir(action_dir):
            if video_file.endswith(".avi"):  # Only process .avi files
                video_path = os.path.join(action_dir, video_file)
                video_output_dir = os.path.join(action_output_dir, os.path.splitext(video_file)[0])
                os.makedirs(video_output_dir, exist_ok=True)

                # Extract and resize frames for this video
                print(f"Processing {video_path}...")
                extract_and_resize_frames(video_path, video_output_dir, frame_size)


# Run the function
process_videos_for_actions(actions, train_dir, output_base_dir, frame_size=(64, 64))
# Out:
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g03_c03.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g03_c03
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g07_c05.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g07_c05
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g21_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g21_c01
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g17_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g17_c01
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g22_c04.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g22_c04
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g05_c07.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g05_c07
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g04_c03.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g04_c03
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g05_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g05_c01
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g10_c03.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g10_c03
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g23_c04.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g23_c04
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g17_c06.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g17_c06
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g23_c03.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g23_c03
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g19_c03.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g19_c03
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g09_c04.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g09_c04
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g23_c02.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g23_c02
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g18_c02.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g18_c02
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g13_c02.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g13_c02
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g10_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g10_c01
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g10_c02.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g10_c02
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g19_c04.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g19_c04
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g05_c05.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g05_c05
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g08_c06.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g08_c06
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g16_c04.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g16_c04
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g10_c06.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g10_c06
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g07_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g07_c01
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g25_c04.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g25_c04
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g04_c04.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g04_c04
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g07_c06.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g07_c06
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g15_c04.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g15_c04
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g25_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g25_c01
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g18_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g18_c01
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g20_c05.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g20_c05
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g09_c03.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g09_c03
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g05_c06.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g05_c06
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g03_c04.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g03_c04
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g06_c05.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g06_c05
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g17_c04.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g17_c04
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g15_c05.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g15_c05
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g21_c07.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g21_c07
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g16_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g16_c01
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g02_c06.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g02_c06
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g08_c02.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g08_c02
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g16_c02.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g16_c02
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g21_c05.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g21_c05
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g14_c02.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g14_c02
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g20_c06.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g20_c06
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g07_c03.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g07_c03
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g20_c07.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g20_c07
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g01_c03.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g01_c03
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g04_c05.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g04_c05
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g24_c02.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g24_c02
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g12_c04.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g12_c04
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g03_c02.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g03_c02
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g11_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g11_c01
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g03_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g03_c01
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g22_c05.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g22_c05
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g24_c05.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g24_c05
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g14_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g14_c01
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g04_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g04_c01
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g13_c03.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g13_c03
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g13_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g13_c01
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g16_c05.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g16_c05
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g06_c04.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g06_c04
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g25_c03.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g25_c03
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g23_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g23_c01
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g09_c02.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g09_c02
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g09_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g09_c01
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g16_c03.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g16_c03
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g20_c04.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g20_c04
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g02_c07.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g02_c07
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g13_c06.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g13_c06
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g01_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g01_c01
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g21_c06.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g21_c06
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g10_c05.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g10_c05
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g01_c02.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g01_c02
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g04_c02.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g04_c02
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_g18_c05.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/Biking/v_Biking_g18_c05
# Processing /kaggle/input/ucf101-action-recognition/train/Biking/v_Biking_
c07.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/JumpingJack/v_JumpingJack_g06_c07
# Processing /kaggle/input/ucf101-action-recognition/train/JumpingJack/v_JumpingJack_g03_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/JumpingJack/v_JumpingJack_g03_c01
# Processing /kaggle/input/ucf101-action-recognition/train/JumpingJack/v_JumpingJack_g11_c04.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/JumpingJack/v_JumpingJack_g11_c04
# Processing /kaggle/input/ucf101-action-recognition/train/JumpingJack/v_JumpingJack_g01_c04.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/JumpingJack/v_JumpingJack_g01_c04
# Processing /kaggle/input/ucf101-action-recognition/train/JumpingJack/v_JumpingJack_g10_c04.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/JumpingJack/v_JumpingJack_g10_c04
# Processing /kaggle/input/ucf101-action-recognition/train/JumpingJack/v_JumpingJack_g10_c03.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/JumpingJack/v_JumpingJack_g10_c03
# Processing /kaggle/input/ucf101-action-recognition/train/JumpingJack/v_JumpingJack_g01_c07.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/JumpingJack/v_JumpingJack_g01_c07
# Processing /kaggle/input/ucf101-action-recognition/train/JumpingJack/v_JumpingJack_g04_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/JumpingJack/v_JumpingJack_g04_c01
# Processing /kaggle/input/ucf101-action-recognition/train/JumpingJack/v_JumpingJack_g24_c04.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/JumpingJack/v_JumpingJack_g24_c04
# Processing /kaggle/input/ucf101-action-recognition/train/JumpingJack/v_JumpingJack_g24_c03.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/JumpingJack/v_JumpingJack_g24_c03
# Processing /kaggle/input/ucf101-action-recognition/train/JumpingJack/v_JumpingJack_g18_c03.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/JumpingJack/v_JumpingJack_g18_c03
# Processing /kaggle/input/ucf101-action-recognition/train/JumpingJack/v_JumpingJack_g01_c06.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/JumpingJack/v_JumpingJack_g01_c06
# Processing /kaggle/input/ucf101-action-recognition/train/JumpingJack/v_JumpingJack_g08_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/JumpingJack/v_JumpingJack_g08_c01
# Processing /kaggle/input/ucf101-action-recognition/train/JumpingJack/v_JumpingJack_g05_c05.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/JumpingJack/v_JumpingJack_g05_c05
# Processing /kaggle/input/ucf101-action-recognition/train/JumpingJack/v_JumpingJack_g23_c04.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/JumpingJack/v_JumpingJack_g23_c04
# Processing /kaggle/input/ucf101-action-recognition/train/JumpingJack/v_JumpingJack_g13_c06.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/JumpingJack/v_JumpingJack_g13_c06
# Processing /kaggle/input/ucf101-action-recognition/train/JumpingJack/v_JumpingJack_g14_c03.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/JumpingJack/v_JumpingJack_g14_c03
# Processing /kaggle/input/ucf101-action-recognition/train/JumpingJack/v_JumpingJack_g06_c01.avi...
# ...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g23_c04
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g24_c06.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g24_c06
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g20_c03.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g20_c03
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g09_c04.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g09_c04
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g10_c02.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g10_c02
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g19_c04.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g19_c04
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g24_c05.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g24_c05
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g12_c05.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g12_c05
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g22_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g22_c01
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g09_c05.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g09_c05
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g16_c02.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g16_c02
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g07_c02.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g07_c02
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g07_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g07_c01
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g17_c05.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g17_c05
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g06_c02.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g06_c02
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g22_c03.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g22_c03
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g19_c03.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g19_c03
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g06_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g06_c01
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g12_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g12_c01
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g20_c04.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g20_c04
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g14_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g14_c01
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g15_c04.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g15_c04
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g03_c03.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g03_c03
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g24_c03.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g24_c03
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g12_c02.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g12_c02
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g04_c04.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g04_c04
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g20_c05.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g20_c05
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g05_c05.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g05_c05
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g09_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g09_c01
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g03_c04.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g03_c04
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g16_c05.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g16_c05
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g13_c04.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g13_c04
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g08_c05.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g08_c05
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g11_c04.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g11_c04
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g20_c02.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g20_c02
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g17_c04.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g17_c04
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g21_c03.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g21_c03
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g21_c04.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g21_c04
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g08_c02.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g08_c02
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g12_c04.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g12_c04
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g23_c03.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g23_c03
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g18_c03.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g18_c03
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g08_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g08_c01
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g18_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g18_c01
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g24_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g24_c01
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g11_c03.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g11_c03
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g25_c04.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g25_c04
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g01_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g01_c01
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g02_c03.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g02_c03
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g17_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g17_c01
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g11_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g11_c01
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g15_c02.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g15_c02
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g10_c04.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g10_c04
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g03_c05.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g03_c05
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g10_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g10_c01
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g19_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g19_c01
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g01_c03.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g01_c03
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g25_c02.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g25_c02
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g15_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g15_c01
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g08_c03.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g08_c03
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g21_c02.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g21_c02
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g05_c04.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g05_c04
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g04_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g04_c01
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g13_c03.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g13_c03
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g05_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g05_c01
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g03_c02.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g03_c02
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g14_c03.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g14_c03
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g25_c03.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g25_c03
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g23_c01.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g23_c01
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g14_c02.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g14_c02
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g23_c02.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g23_c02
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g02_c06.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g02_c06
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g02_c05.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g02_c05
# Processing /kaggle/input/ucf101-action-recognition/train/WalkingWithDog/v_WalkingWithDog_g07_c05.avi...
# Frames resized to (64, 64) and saved to /kaggle/working/extracted_frames/WalkingWithDog/v_WalkingWithDog_g07_c05

# %%
# Load the data
base_dir = "/kaggle/working/extracted_frames"
actions = {"Biking","PushUps","JumpingJack","WalkingWithDog","WallPushups"}
seq_length = 20

# %%
import numpy as np
import os
import cv2

def action_data_generator(base_dir, actions, seq_length=20, frame_size=(64, 64), batch_size=32):
    action_to_label = {action: i for i, action in enumerate(actions)}
    action_iterators = {action: iter(os.listdir(os.path.join(base_dir, action))) for action in actions}

    while True:
        X, y = [], []
        for action in actions:
            action_dir = os.path.join(base_dir, action)

            if not os.path.exists(action_dir):
                print(f"Action directory not found: {action_dir}")
                continue

            # Load videos for the current action
            video_dir_list = os.listdir(action_dir)
            for video_dir in video_dir_list:
                video_path = os.path.join(action_dir, video_dir)
                if os.path.isdir(video_path):
                    frames = []
                    for frame_file in sorted(os.listdir(video_path)):
                        frame_path = os.path.join(video_path, frame_file)
                        frame = cv2.imread(frame_path)
                        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                        frame = cv2.resize(frame, frame_size)
                        frames.append(frame / 255.0)

                    # Create sequences
                    for i in range(len(frames) - seq_length):
                        X.append(frames[i:i + seq_length])
                        y.append(frames[i + 1:i + seq_length + 1])

                        if len(X) == batch_size:
                            yield np.array(X), np.array(y)
                            X, y = [], []
        
        # Yield any remaining samples
        if X:
            yield np.array(X), np.array(y)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import ConvLSTM2D, BatchNormalization, Conv3D


def build_predrnn(input_shape):
    """
    Build an RNN for frame prediction.
    """
    model = Sequential([
        ConvLSTM2D(filters=64, kernel_size=(3, 3), padding='same', return_sequences=True, input_shape=input_shape),
        BatchNormalization(),
        ConvLSTM2D(filters=64, kernel_size=(3, 3), padding='same', return_sequences=True),
        BatchNormalization(),
        Conv3D(filters=3, kernel_size=(3, 3, 3), activation='sigmoid', padding='same')  # Predict RGB frames
    ])
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model

# %%
# For batch training
input_shape = (10, 64, 64,3)
model = build_predrnn(input_shape)
data_gen = action_data_generator(base_dir, actions, seq_length=20, batch_size=16)
model.fit(data_gen, steps_per_epoch=100, epochs=50)
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1733230576.580908    1925 service.cc:145] XLA service 0x7ec1e005af40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1733230576.580980    1925 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1733230583.124833    1925 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 66s 561ms/step - loss: 0.0474 - mae: 0.1566
# Epoch 2/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0080 - mae: 0.0680
# Epoch 3/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0178 - mae: 0.1025
# Epoch 4/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0089 - mae: 0.0718
# Epoch 5/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0114 - mae: 0.0824
# Epoch 6/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0107 - mae: 0.0799
# Epoch 7/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0087 - mae: 0.0737
# Epoch 8/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0055 - mae: 0.0582
# Epoch 9/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0078 - mae: 0.0671
# Epoch 10/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0107 - mae: 0.0803
# Epoch 11/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0068 - mae: 0.0665
# Epoch 12/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0056 - mae: 0.0566
# Epoch 13/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0110 - mae: 0.0835
# Epoch 14/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0086 - mae: 0.0738
# Epoch 15/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 562ms/step - loss: 0.0174 - mae: 0.1003
# Epoch 16/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0232 - mae: 0.1123
# Epoch 17/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0087 - mae: 0.0716
# Epoch 18/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0234 - mae: 0.1146
# Epoch 19/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0057 - mae: 0.0555
# Epoch 20/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0177 - mae: 0.1000
# Epoch 21/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0129 - mae: 0.0896
# Epoch 22/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 560ms/step - loss: 0.0117 - mae: 0.0838
# Epoch 23/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0052 - mae: 0.0562
# Epoch 24/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0071 - mae: 0.0611
# Epoch 25/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0060 - mae: 0.0596
# Epoch 26/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0062 - mae: 0.0582
# Epoch 27/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0043 - mae: 0.0492
# Epoch 28/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0093 - mae: 0.0702
# Epoch 29/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0057 - mae: 0.0573
# Epoch 30/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0045 - mae: 0.0513
# Epoch 31/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0043 - mae: 0.0496
# Epoch 32/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 560ms/step - loss: 0.0089 - mae: 0.0723
# Epoch 33/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 562ms/step - loss: 0.0052 - mae: 0.0553
# Epoch 34/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 560ms/step - loss: 0.0063 - mae: 0.0619
# Epoch 35/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0035 - mae: 0.0423
# Epoch 36/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0095 - mae: 0.0739
# Epoch 37/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0089 - mae: 0.0691
# Epoch 38/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 61s 612ms/step - loss: 0.0108 - mae: 0.0808
# Epoch 39/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0035 - mae: 0.0455
# Epoch 40/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0066 - mae: 0.0615
# Epoch 41/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0054 - mae: 0.0554
# Epoch 42/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0041 - mae: 0.0476
# Epoch 43/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0037 - mae: 0.0465
# Epoch 44/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0050 - mae: 0.0555
# Epoch 45/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0031 - mae: 0.0419
# Epoch 46/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0035 - mae: 0.0434
# Epoch 47/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0050 - mae: 0.0523
# Epoch 48/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0027 - mae: 0.0402
# Epoch 49/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0032 - mae: 0.0419
# Epoch 50/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 56s 561ms/step - loss: 0.0041 - mae: 0.0500

# %%
model.save("predrnn_model.keras")  # Save the model in the SavedModel format
